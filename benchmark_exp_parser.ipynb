# %%
import os
import pickle
import numpy as np

# %%
imputation_method = 'SINKHORN'
metric = 'auc_ovo'

params = {
    'IRIS': {
        'n_imputations': 20,
        'n_runs': 200,
        'epochs': 50,
        'alpha': 1.,
    },
    'AUSTRALIAN': {
        'n_imputations': 20,
        'n_runs': 200,
        'epochs': 20,
        'alpha': 1.,
    },
    'WINE': {
        'n_imputations': 20,
        'n_runs': 200,
        'epochs': 50,
        'alpha': 1.,
    },
    'PIMA': {
        'n_imputations': 20,
        'n_runs': 200,
        'epochs': 50,
        'alpha': 1.,
    },
    'ABALONE': {
        'n_imputations': 20,
        'n_runs': 200,
        'epochs': 50,
        'alpha': .3,
    },
}

datasets = list(params.keys())

clean_datasets = {
    'IRIS': 'IRIS',
    'AUSTRALIAN': 'STATL',
    'WINE': 'WINE',
    'PIMA': 'PIMA',
    'ABALONE': 'ABAL',
}

approaches = [
    'SINGLE',
    'MULTIPLE',
    'SINGLE-HOT-PATCH',
    'HOT-PATCH',
]

clean_approaches = {
    'SINGLE': 'SI',
    'MULTIPLE': 'MI',
    'SINGLE-HOT-PATCH': 'S-HOT',
    'HOT-PATCH': 'M-HOT',
}

missing_modes = ['MCAR', 'MAR', 'MNAR']
missing_rates = [.1, .15, .25]
num_lines = len(missing_modes) * len(missing_rates)

# %%
def get_ranks(array):
    vals, inverse, count = np.unique(array, return_inverse=True, return_counts=True)
    idx_vals_repeated = np.where(count > 1)[0]
    rows, cols = np.where(inverse == idx_vals_repeated[:, np.newaxis])
    _, inverse_rows = np.unique(rows, return_index=True)
    indices_of_repeated = np.split(cols, inverse_rows[1:])
    order = (-np.array(array)).argsort()
    ranks = order.argsort() * 1. + 1.
    for indices in indices_of_repeated:
        if len(indices) > 0:
            mean_rank = np.mean(ranks[indices])
            ranks[indices] = mean_rank
    return ranks


print('\\hline')
line = 'Dataset & \\multicolumn{2}{l|}{Pattern} & '
line += f'\\multicolumn{{2}}{{l|}}{{\\textit{{{clean_approaches["SINGLE"]}}}}} & '
line += f'\\multicolumn{{2}}{{l|}}{{\\textit{{{clean_approaches["MULTIPLE"]}}}}} & '
line += f'\\multicolumn{{2}}{{l|}}{{\\textit{{{clean_approaches["SINGLE-HOT-PATCH"]}}}}} & '
line += f'\\multicolumn{{2}}{{l|}}{{\\textit{{{clean_approaches["HOT-PATCH"]}}}}} \\\\'
print(line)
print('\\hline')

all_ranks = []
for dataset in datasets:
    n_imputations = params[dataset]['n_imputations']
    n_runs = params[dataset]['n_runs']
    epochs = params[dataset]['epochs']
    alpha = params[dataset]['alpha']
    for i, missing_mode in enumerate(missing_modes):
        if i > 0:
            print(f'\\cline{{2-{len(approaches) * 2 + 3}}}')
        for j, missing_rate in enumerate(missing_rates):
            exp_name = f'{dataset}_{missing_mode}_{f"{missing_rate:.02f}".split(".")[-1]}_' + \
                       f'n{n_imputations}_r{n_runs}_e{epochs}_a{str(alpha).replace(".", "_")}'
            if os.path.isfile(f'results/{exp_name}.pickle'):
                metrics = pickle.load(open(f'results/{exp_name}.pickle', 'rb'))
                line = f'\\multirow{{{num_lines}}}{{*}}{{{clean_datasets[dataset]}}} &' if i + j == 0 else '&'
                line += f' \\multirow{{{len(missing_rates)}}}{{*}}{{{missing_mode}}} &' if j == 0 else ' &'
                line += f' {round(missing_rate * 100.)}\\% &'
                v = {}
                values = []
                for approach in approaches:
                    v[approach] = round(np.mean(metrics[imputation_method][approach][metric]) / 100., 7)
                    values.append(v[approach])
                ranks = get_ranks(values)
                all_ranks.append(ranks)
                for k, approach in enumerate(approaches):
                    bold = v[approach] == max(values)
                    line += f' $\\mathbf{{{v[approach]:.07f}}}$ &' if bold else f' ${v[approach]:.07f}$ &'
                    line += f' ({int(ranks[k]) if ranks[k].is_integer() else ranks[k]})'
                    if k < len(approaches) - 1:
                        line += ' &'
                print(line + ' \\\\')
    print('\\hline')
line = f'\\multicolumn{{3}}{{|l|}}{{Average rank}}'
for r in np.array(all_ranks).mean(axis=0):
    line += f' & \\multicolumn{{2}}{{c|}}{{{r:.04f}}}'
print(line + ' \\\\')
print('\\hline')
# Out:
# \hline
# Dataset & \multicolumn{2}{l|}{Pattern} & \multicolumn{2}{l|}{\textit{SI}} & \multicolumn{2}{l|}{\textit{MI}} & \multicolumn{2}{l|}{\textit{S-HOT}} & \multicolumn{2}{l|}{\textit{M-HOT}} \\
# \hline
# \multirow{9}{*}{IRIS} & \multirow{3}{*}{MCAR} & 10\% & $0.9958323$ & (4) & $\mathbf{0.9973218}$ & (1) & $0.9968544$ & (3) & $0.9972525$ & (2) \\
# & & 15\% & $0.9947010$ & (4) & $0.9967011$ & (2) & $0.9961452$ & (3) & $\mathbf{0.9967655}$ & (1) \\
# & & 25\% & $0.9879101$ & (4) & $0.9931490$ & (2) & $0.9920251$ & (3) & $\mathbf{0.9933714}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MAR} & 10\% & $0.9977831$ & (4) & $\mathbf{0.9983718}$ & (1) & $0.9980598$ & (3) & $0.9983512$ & (2) \\
# & & 15\% & $0.9964883$ & (4) & $0.9969672$ & (2) & $0.9966728$ & (3) & $\mathbf{0.9970707}$ & (1) \\
# & & 25\% & $0.9934700$ & (4) & $0.9940230$ & (2) & $0.9937325$ & (3) & $\mathbf{0.9940345}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MNAR} & 10\% & $0.9968828$ & (4) & $0.9975337$ & (2) & $0.9969866$ & (3) & $\mathbf{0.9975402}$ & (1) \\
# & & 15\% & $0.9922183$ & (4) & $0.9953051$ & (2) & $0.9939836$ & (3) & $\mathbf{0.9953053}$ & (1) \\
# & & 25\% & $0.9800315$ & (4) & $\mathbf{0.9893560}$ & (1) & $0.9851027$ & (3) & $0.9882223$ & (2) \\
# \hline
# \multirow{9}{*}{STATL} & \multirow{3}{*}{MCAR} & 10\% & $0.9004228$ & (4) & $\mathbf{0.9122272}$ & (1) & $0.9099691$ & (3) & $0.9119025$ & (2) \\
# & & 15\% & $0.8893594$ & (4) & $0.9048134$ & (2) & $0.9026763$ & (3) & $\mathbf{0.9050871}$ & (1) \\
# & & 25\% & $0.8766682$ & (4) & $0.8979225$ & (2) & $0.8956989$ & (3) & $\mathbf{0.8987079}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MAR} & 10\% & $0.9075065$ & (4) & $\mathbf{0.9157279}$ & (1) & $0.9135148$ & (3) & $0.9153541$ & (2) \\
# & & 15\% & $0.9002249$ & (4) & $0.9083954$ & (2) & $0.9072489$ & (3) & $\mathbf{0.9085098}$ & (1) \\
# & & 25\% & $0.8919708$ & (4) & $0.9031956$ & (2) & $0.9009516$ & (3) & $\mathbf{0.9033104}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MNAR} & 10\% & $0.8966214$ & (4) & $0.9067652$ & (2) & $0.9043305$ & (3) & $\mathbf{0.9076346}$ & (1) \\
# & & 15\% & $0.8953022$ & (4) & $0.9072963$ & (2) & $0.9049765$ & (3) & $\mathbf{0.9077530}$ & (1) \\
# & & 25\% & $0.8724639$ & (4) & $0.8940123$ & (2) & $0.8917990$ & (3) & $\mathbf{0.8946876}$ & (1) \\
# \hline
# \multirow{9}{*}{WINE} & \multirow{3}{*}{MCAR} & 10\% & $0.9986694$ & (4) & $0.9988537$ & (2) & $0.9987253$ & (3) & $\mathbf{0.9988668}$ & (1) \\
# & & 15\% & $0.9975506$ & (4) & $\mathbf{0.9979885}$ & (1) & $0.9976749$ & (3) & $0.9979830$ & (2) \\
# & & 25\% & $0.9947814$ & (4) & $0.9958397$ & (2) & $0.9956436$ & (3) & $\mathbf{0.9958428}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MAR} & 10\% & $0.9963918$ & (4) & $0.9968344$ & (2) & $0.9966461$ & (3) & $\mathbf{0.9969354}$ & (1) \\
# & & 15\% & $0.9978826$ & (4) & $0.9986410$ & (2) & $0.9984737$ & (3) & $\mathbf{0.9986593}$ & (1) \\
# & & 25\% & $0.9966551$ & (4) & $0.9976426$ & (2) & $0.9973227$ & (3) & $\mathbf{0.9977587}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MNAR} & 10\% & $0.9990950$ & (4) & $\mathbf{0.9991486}$ & (1) & $0.9991137$ & (3) & $0.9991412$ & (2) \\
# & & 15\% & $0.9981937$ & (4) & $0.9984342$ & (2) & $0.9982292$ & (3) & $\mathbf{0.9984523}$ & (1) \\
# & & 25\% & $0.9901818$ & (4) & $0.9948135$ & (2) & $0.9940507$ & (3) & $\mathbf{0.9948292}$ & (1) \\
# \hline
# \multirow{9}{*}{PIMA} & \multirow{3}{*}{MCAR} & 10\% & $0.8183348$ & (4) & $0.8225089$ & (2) & $0.8207717$ & (3) & $\mathbf{0.8225461}$ & (1) \\
# & & 15\% & $0.8060807$ & (4) & $\mathbf{0.8123862}$ & (1) & $0.8103984$ & (3) & $0.8123352$ & (2) \\
# & & 25\% & $0.7932394$ & (4) & $0.8040140$ & (2) & $0.8020177$ & (3) & $\mathbf{0.8055621}$ & (1) \\
# \cline{2-11}
# & \multirow{3}{*}{MAR} & 10\% & $0.8201186$ & (4) & $\mathbf{0.8235582}$ & (1) & $0.8218285$ & (3) & $0.8235392$ & (2) \\
# & & 15\% & $0.8078931$ & (4) & $\mathbf{0.8143046}$ & (1) & $0.8127261$ & (3) & $0.8142421$ & (2) \\
# & & 25\% & $0.7989430$ & (4) & $\mathbf{0.8072073}$ & (1) & $0.8058399$ & (3) & $0.8071192$ & (2) \\
# \cline{2-11}
# & \multirow{3}{*}{MNAR} & 10\% & $0.8250540$ & (4) & $0.8299199$ & (2) & $0.8278898$ & (3) & $\mathbf{0.8303720}$ & (1) \\
# & & 15\% & $0.8137489$ & (4) & $0.8211264$ & (2) & $0.8189948$ & (3) & $\mathbf{0.8213390}$ & (1) \\
# & & 25\% & $0.7916129$ & (4) & $0.8035721$ & (2) & $0.8011662$ & (3) & $\mathbf{0.8036587}$ & (1) \\
# \hline
# \multirow{9}{*}{ABAL} & \multirow{3}{*}{MCAR} & 10\% & $0.8655977$ & (4) & $0.8707151$ & (2) & $\mathbf{0.8707402}$ & (1) & $0.8707068$ & (3) \\
# & & 15\% & $0.8604767$ & (4) & $0.8674447$ & (2) & $\mathbf{0.8680851}$ & (1) & $0.8673406$ & (3) \\
# & & 25\% & $0.8495787$ & (4) & $0.8596208$ & (2) & $\mathbf{0.8621626}$ & (1) & $0.8592872$ & (3) \\
# \cline{2-11}
# & \multirow{3}{*}{MAR} & 10\% & $0.8665143$ & (4) & $0.8708308$ & (2) & $\mathbf{0.8711025}$ & (1) & $0.8708024$ & (3) \\
# & & 15\% & $0.8613696$ & (4) & $0.8678045$ & (2) & $\mathbf{0.8689452}$ & (1) & $0.8676311$ & (3) \\
# & & 25\% & $0.8518054$ & (4) & $0.8612268$ & (2) & $\mathbf{0.8642873}$ & (1) & $0.8608408$ & (3) \\
# \cline{2-11}
# & \multirow{3}{*}{MNAR} & 10\% & $0.8697805$ & (4) & $0.8743051$ & (3) & $\mathbf{0.8746136}$ & (1) & $0.8743183$ & (2) \\
# & & 15\% & $0.8651282$ & (4) & $0.8716987$ & (2) & $\mathbf{0.8728212}$ & (1) & $0.8715489$ & (3) \\
# & & 25\% & $0.8518229$ & (4) & $0.8614111$ & (2) & $\mathbf{0.8642183}$ & (1) & $0.8609479$ & (3) \\
# \hline
# \multicolumn{3}{|l|}{Average rank} & \multicolumn{2}{c|}{4.0000} & \multicolumn{2}{c|}{1.7778} & \multicolumn{2}{c|}{2.6000} & \multicolumn{2}{c|}{1.6222} \\
# \hline

# %%
def chi_2(N, k, ranks):
    s = 0
    for rank in ranks:
        s += rank**2
    first = (12 * N) / (k * (k + 1))
    second = s - (k * (k + 1)**2 / 4)
    return first * second

def FF(N, k, chi2):
    return ((N - 1) * chi2) / ((N * (k - 1)) - chi2)

N = len(datasets) * num_lines
k = len(approaches)
ranks = np.array(all_ranks).mean(axis=0)

chi2 = chi_2(N, k, ranks)
print(f'chi2: {chi2}')

ff = FF(N, k, chi2)
print(f'ff: {ff}')

print(f'CD: {2.569 * ((k * (k + 1)) / (6 * N))**.5}')
# Out:
# chi2: 95.90666666666667
# ff: 107.94406548431105
# CD: 0.6991932388011094
